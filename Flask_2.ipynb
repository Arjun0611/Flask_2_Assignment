# %%
#Q1.

# GET is used for retrieving data, while POST is used for submitting data to be processed.
# For GET, parameters are passed in the URL as a query string, visible to users and can be bookmarked.
# For POST, parameters are sent in the request body, not visible in the URL, making it more secure for sensitive information.

# %%
#Q2.

# 'request' object is useful when handling form submissions, user authentication, and processing API calls. It allows one to access user input, validate data, and perform necessary actions based on the user's request.
# In short, it is essential for handling and processing incoming HTTP requests, making it a fundamental component for building web apps that respond to user interactions and input.

# %%
#Q3.

# 'redirect' is used to redirect the client's browser to a different URL. It is used after handling a form submission or processing some data to redirect the user to a different page, such as a thank-you page or a different route in the application

# %%
#Q4.

# Templates are HTML files that allow one to separate the presentation layer from the application logic.

# 'render_template()' function allows one to render these templates with dynamic data from Flask application, making it more flexible and promoting code reusability.

# %%
#Q5.

# I am creating a simple API to manage a to-do list. The API enables users to perform Create, Read, Update, Delete operations on tasks in the to-do list.

# %%
# Reading a to-do list that encompasses two predefined tasks by executing GET method using Postman
# Appending one more task to the to-do list by executing the POST method using Postman.

# %% [markdown]
# ![GET.png](attachment:918ea6fa-5064-4a7d-b188-5889eefee916.png)![POST.png](attachment:63fd8dd1-fc43-4476-86a7-099a123d8858.png)
